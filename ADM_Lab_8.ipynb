# %% [markdown]
# <a href="https://colab.research.google.com/github/NithinReddychallagonda/Data-Mining/blob/main/ADM_Lab_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Employee Salary Analysis

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data={
    'Employee': ['John', 'Sarah', 'Mike', 'Emma', 'Tom'],
    'Department': ['IT', 'HR', 'IT', 'Finance', 'HR'],
    'Salary': [60000, 50000, 75000, 65000, 48000],
    'Experience (Years)': [5, 3, 7, 4, 2],
    'Performance Rating (Out of 5)': [4.5, 3.8, 4.9, 4.2, 3.5]
}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         IT   60000                   5
# 1    Sarah         HR   50000                   3
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)
# 0                            4.5
# 1                            3.8
# 2                            4.9
# 3                            4.2
# 4                            3.5

# %%
avg_salary_by_dept=df.groupby('Department')['Salary'].mean()
avg_salary_by_dept
# Out:
# Department
# Finance    65000.0
# HR         49000.0
# IT         67500.0
# Name: Salary, dtype: float64

# %%
high_performers=df[df['Performance Rating (Out of 5)']>=4.0]
high_performers
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         IT   60000                   5
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
#
#    Performance Rating (Out of 5)
# 0                            4.5
# 2                            4.9
# 3                            4.2

# %%
def calculate_increment(rating):
  if rating>=4.0:
    return 0.10
  else:
    return 0.05
df['Increment']=df['Performance Rating (Out of 5)'].apply(calculate_increment)
df
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         IT   60000                   5
# 1    Sarah         HR   50000                   3
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)  Increment
# 0                            4.5       0.10
# 1                            3.8       0.05
# 2                            4.9       0.10
# 3                            4.2       0.10
# 4                            3.5       0.05

# %%
df['salary_after_increment']=df['Salary']+(df['Salary']*df['Increment'])
df
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 0     John         IT   60000                   5
# 1    Sarah         HR   50000                   3
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)  Increment  salary_after_increment
# 0                            4.5       0.10                 66000.0
# 1                            3.8       0.05                 52500.0
# 2                            4.9       0.10                 82500.0
# 3                            4.2       0.10                 71500.0
# 4                            3.5       0.05                 50400.0

# %%
sorted_df = df.sort_values(by='salary_after_increment', ascending=False)
print(sorted_df)
# Out:
#   Employee Department  Salary  Experience (Years)  \
# 2     Mike         IT   75000                   7
# 3     Emma    Finance   65000                   4
# 0     John         IT   60000                   5
# 1    Sarah         HR   50000                   3
# 4      Tom         HR   48000                   2
#
#    Performance Rating (Out of 5)  Increment  salary_after_increment
# 2                            4.9       0.10                 82500.0
# 3                            4.2       0.10                 71500.0
# 0                            4.5       0.10                 66000.0
# 1                            3.8       0.05                 52500.0
# 4                            3.5       0.05                 50400.0

# %% [markdown]
# #COVID-19 Cases Analysis

# %%
cdata={
    'City':['New York','Los Angeles','Chicago','Houston','Miami'],
    'Total Cases':[100000,85000,65000,70000,55000],
    'Recovered':[75000,70000,50000,60000,45000],
    'Deaths':[5000,3500,2500,2000,1500]
}

# %%
df=pd.DataFrame(cdata)
df
# Out:
#           City  Total Cases  Recovered  Deaths
# 0     New York       100000      75000    5000
# 1  Los Angeles        85000      70000    3500
# 2      Chicago        65000      50000    2500
# 3      Houston        70000      60000    2000
# 4        Miami        55000      45000    1500

# %%
df['recovery_rate']=(df['Recovered']/df['Total Cases'])*100
df
# Out:
#           City  Total Cases  Recovered  Deaths  recovery_rate
# 0     New York       100000      75000    5000      75.000000
# 1  Los Angeles        85000      70000    3500      82.352941
# 2      Chicago        65000      50000    2500      76.923077
# 3      Houston        70000      60000    2000      85.714286
# 4        Miami        55000      45000    1500      81.818182

# %%
df['death_rate']=(df['Deaths']/df['Total Cases'])*100
df
# Out:
#           City  Total Cases  Recovered  Deaths  recovery_rate  death_rate
# 0     New York       100000      75000    5000      75.000000    5.000000
# 1  Los Angeles        85000      70000    3500      82.352941    4.117647
# 2      Chicago        65000      50000    2500      76.923077    3.846154
# 3      Houston        70000      60000    2000      85.714286    2.857143
# 4        Miami        55000      45000    1500      81.818182    2.727273

# %%
death_rate_by_city=df[df['death_rate']>=0.05]
death_rate_by_city
# Out:
#           City  Total Cases  Recovered  Deaths  recovery_rate  death_rate
# 0     New York       100000      75000    5000      75.000000    5.000000
# 1  Los Angeles        85000      70000    3500      82.352941    4.117647
# 2      Chicago        65000      50000    2500      76.923077    3.846154
# 3      Houston        70000      60000    2000      85.714286    2.857143
# 4        Miami        55000      45000    1500      81.818182    2.727273

# %%
sorted_df = df.sort_values(by='recovery_rate', ascending=False)
print(sorted_df)
# Out:
#           City  Total Cases  Recovered  Deaths  recovery_rate  death_rate
# 3      Houston        70000      60000    2000      85.714286    2.857143
# 1  Los Angeles        85000      70000    3500      82.352941    4.117647
# 4        Miami        55000      45000    1500      81.818182    2.727273
# 2      Chicago        65000      50000    2500      76.923077    3.846154
# 0     New York       100000      75000    5000      75.000000    5.000000

# %%
total_cases=df['Total Cases'].sum()
total_deaths=df['Deaths'].sum()
print("Total Cases:",total_cases)
print("Total Deaths:",total_deaths)
# Out:
# Total Cases: 375000
# Total Deaths: 14500
